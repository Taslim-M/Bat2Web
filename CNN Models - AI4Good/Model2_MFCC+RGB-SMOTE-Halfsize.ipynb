# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
# Out:
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import keras
import pandas as pd
import tensorflow as tf

import numpy as np
# from keras.models import Sequential, Model
# from keras.layers import Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import np_utils

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D, GlobalAveragePooling2D, Input,AveragePooling2D, BatchNormalization, LeakyReLU

# from keras.applications import MobileNet
# from keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2, InceptionV3
from tensorflow.keras.optimizers import Adam

from matplotlib import pyplot as plt
import os
from sklearn.model_selection import train_test_split

import seaborn as sns
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import KFold

from collections import defaultdict,Counter
from imblearn.over_sampling import SMOTE
from PIL import Image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <h2>Data Loading and Preparation</h2>

# %%
def getSpeciesCode(x):
    part = x.split('_')
    if part[0] == 'ASETRI':
        return 0
    elif part[0] == 'EPTBOT':
        return 1
    elif part[0] == 'MYOEMA':
        return 2
    elif part[0] == 'PIPKUH':
        return 3
    elif part[0] == 'RHIMUS':
        return 4
    elif part[0] == 'RHYNAS':
        return 5
    elif part[0] == 'ROUAEG':
        return 6
    elif part[0] == 'TAPPER':
        return 7
    else:
        return 'Unknown'
    
def getSpecies(x):
    if x == 0:
        return 'A.tridens'
    elif x == 1:
        return 'E.bottae'
    elif x == 2:
        return 'M.emarginatus'
    elif x == 3:
        return 'P.kuhli'
    elif x == 4:
        return 'R.muscatellum'
    elif x == 5:
        return 'R.nasutus'
    elif x == 6:
        return 'R.aegyptius'
    elif x == 7:
        return 'T.perforatus'
    else:
        return 'Unknown'

# Ytrain in Onehot encoded form 
def makeOverSamplesSMOTE(X_train,Y_train):
    
    Y_train_labelled=[]
    X_dims=X_train.shape

    for i in range(len(Y_train)):
        Y_train_labelled.append(np.argmax(Y_train[i]))

    print('Original trainingset shape %s' %  [(getSpecies(k),v) for k,v in Counter(Y_train_labelled).items()])       
    X_train= X_train.reshape(-1,X_dims[1]*X_dims[2]*X_dims[3])

    sm = SMOTE(sampling_strategy='all',k_neighbors=5)
    X_train, Y_train_labelled = sm.fit_resample(X_train, Y_train_labelled)


    print('Resampled training set shape %s' % [(getSpecies(k),v) for k,v in Counter(Y_train_labelled).items()])


    #reshape X_all
    X_train= X_train.reshape(-1,X_dims[1],X_dims[2],X_dims[3])

    # update Y_train
    Y_train= np_utils.to_categorical(Y_train_labelled, num_classes=8)

    print("After OverSampling\nX_train: shape= ",X_train.shape)
    print("Y_train: shape= ",Y_train.shape)

    
    
    return(X_train,Y_train)

# %%
image_folder_path = '../data/MFCCRefined'
file_paths = [f for f in os.listdir(image_folder_path)]
species = []
for file_name in file_paths:
    sp = file_name.split('_')
    species.append(sp[0])

df = pd.DataFrame(species, columns=['Species'])
df['Species'].value_counts()
# Out:
# RHIMUS    1665
# TAPPER     403
# PIPKUH     299
# RHYNAS     269
# EPTBOT     124
# ROUAEG     121
# MYOEMA     112
# ASETRI      25
# Name: Species, dtype: int64

# %%
X_all = []
Y_all = []

image_folder_path = '../data/MFCCRefined'
file_paths = [f for f in os.listdir(image_folder_path)]

for file_name in file_paths:
    spectrogram = Image.open(image_folder_path + '/' + file_name)
    spectrogram = spectrogram.convert('RGB')
    spectrogram = spectrogram.resize((170, 112))  
    spectrogram = np.array(spectrogram)
    #spectrogram = np.expand_dims(spectrogram, axis=2) 
    X_all.append(spectrogram)
    Y_all.append(getSpeciesCode(file_name))

# %%
X_all = np.array(X_all)
Y_all = np.array(Y_all)

print(X_all.shape)
print(Y_all.shape)

X_all = X_all.astype('float32')
X_all /= 255

Y_all = np_utils.to_categorical(Y_all, num_classes=8)
# Out:
# (3018, 112, 170, 3)
# (3018,)

# %%
# train /test= 80/20% split
# Data is stratified
X_train, X_test, Y_train, Y_test = train_test_split(X_all, Y_all, test_size=0.2, random_state = 245, stratify=Y_all)


X_train, Y_train= makeOverSamplesSMOTE(X_train, Y_train)
# Out:
# Original trainingset shape [('RHYNAS', 217), ('EPTBOT', 105), ('RHIMUS', 1439), ('TAPPER', 343), ('ASETRI', 20), ('PIPKUH', 242), ('MYOEMA', 91), ('ROUAEG', 97)]
# Resampled training set shape [('RHYNAS', 1439), ('EPTBOT', 1439), ('RHIMUS', 1439), ('TAPPER', 1439), ('ASETRI', 1439), ('PIPKUH', 1439), ('MYOEMA', 1439), ('ROUAEG', 1439)]
# After OverSampling
# X_train: shape=  (11512, 224, 341, 3)
# Y_train: shape=  (11512, 8)

# %% [markdown]
# <h2>Model Building</h2>

# %%
   def build_current_model():
    inp = Input(shape=(112,170,3))
    
    c1 = Convolution2D(filters=128,kernel_size=(7,7),strides=(2,2),padding='same')(inp)
    bt = BatchNormalization()(c1)
    bt = Activation('relu')(bt)
    #bt = LeakyReLU(alpha=0.01)(bt)
    mpool = MaxPooling2D(pool_size=(2,2),strides=2,padding='same')(bt)
    mpool = Dropout(0.2)(mpool)

    
    c2 = Convolution2D(filters=256,kernel_size=(5,5),strides=(2,2),padding='same')(mpool)
    bt = BatchNormalization()(c2)
    bt = Activation('relu')(bt)
    #bt = LeakyReLU(alpha=0.01)(bt)
    mpool = AveragePooling2D(pool_size=(2,2),strides=2,padding='same')(bt)
    mpool = Dropout(0.3)(mpool)
    
    c2 = Convolution2D(filters=512,kernel_size=(3,3),strides=(1,1),padding='same')(mpool)
    bt = BatchNormalization()(c2)
    bt = Activation('relu')(bt)
    #bt = LeakyReLU(alpha=0.01)(bt)
    mpool = AveragePooling2D(pool_size=(2,2),strides=2,padding='same')(bt)
    mpool = Dropout(0.3)(mpool)
    
    c3 = Convolution2D(filters=512,kernel_size=(3,3),strides=(1,1),padding='same')(mpool)
    bt = BatchNormalization()(c3)
    bt = Activation('relu')(bt)
    #bt = LeakyReLU(alpha=0.01)(bt)
    mpool = AveragePooling2D(pool_size=(2,2),strides=2,padding='same')(bt)
    mpool = Dropout(0.4)(mpool)
    
    f = Flatten()(mpool)
    
    x_dense = Dense(2048)(f)
    bt = BatchNormalization()(x_dense)
    bt = Activation('relu')(bt)
    bt = Dropout(0.4)(bt)

    
    x_dense = Dense(1024)(bt)
    bt = BatchNormalization()(x_dense)
    bt = Activation('relu')(bt)
    bt = Dropout(0.3)(bt)
    
    x_dense = Dense(512)(bt)
    bt = BatchNormalization()(x_dense)
    bt = Activation('relu')(bt)
    bt = Dropout(0.2)(bt)

    x_out = Dense(8, name='output', activation='softmax')(bt)
    
    model = Model(inputs=inp, outputs=x_out)
    model.compile(optimizer=Adam(lr=0.003), 
                  loss='categorical_crossentropy', 
                  metrics = ['accuracy'])
    return model

# %%
model = build_current_model()
model.summary()
# Out:
# WARNING:tensorflow:From /home/team4/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 112, 170, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 56, 85, 128)       18944
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 85, 128)       512
# _________________________________________________________________
# activation (Activation)      (None, 56, 85, 128)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 43, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 43, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 22, 256)       819456
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 22, 256)       1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 22, 256)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 7, 11, 256)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 11, 256)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 11, 512)        1180160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 11, 512)        2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 11, 512)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 4, 6, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 6, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 6, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 6, 512)         0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 2, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              6293504
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_4 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_5 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# output (Dense)               (None, 8)                 4104
# =================================================================
# Total params: 13,318,920
# Trainable params: 13,308,936
# Non-trainable params: 9,984
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "Model2V8.png", show_shapes=True)

# %%
my_callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=25,verbose=1, mode='min',restore_best_weights=True)]

history = model.fit(X_train, Y_train, 
              epochs = 100, 
              validation_split=0.1, 
              verbose=1, 
              batch_size = 8,
#             class_weight = class_weight
                 callbacks=my_callbacks   )

history_info = history.history
# Out:
# Train on 10360 samples, validate on 1152 samples
# Epoch 1/100
# 10360/10360 [==============================] - 48s 5ms/sample - loss: 1.1303 - acc: 0.6219 - val_loss: 4.0711 - val_acc: 0.1276
# Epoch 2/100
# 10360/10360 [==============================] - 47s 5ms/sample - loss: 0.6060 - acc: 0.7862 - val_loss: 2.1862 - val_acc: 0.2795
# Epoch 3/100
# 10360/10360 [==============================] - 47s 5ms/sample - loss: 0.4493 - acc: 0.8482 - val_loss: 3.2620 - val_acc: 0.1936
# Epoch 4/100
# 10360/10360 [==============================] - 48s 5ms/sample - loss: 0.3472 - acc: 0.8837 - val_loss: 1.3615 - val_acc: 0.6007
# Epoch 5/100
# 10360/10360 [==============================] - 48s 5ms/sample - loss: 0.3050 - acc: 0.9009 - val_loss: 0.6056 - val_acc: 0.7977
# Epoch 6/100
# 10360/10360 [==============================] - 48s 5ms/sample - loss: 0.2411 - acc: 0.9217 - val_loss: 0.4586 - val_acc: 0.8481
# Epoch 7/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.2138 - acc: 0.9294 - val_loss: 0.6264 - val_acc: 0.7648
# Epoch 8/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1916 - acc: 0.9394 - val_loss: 0.8555 - val_acc: 0.7031
# Epoch 9/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1538 - acc: 0.9505 - val_loss: 0.5062 - val_acc: 0.8194
# Epoch 10/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1468 - acc: 0.9540 - val_loss: 0.4959 - val_acc: 0.7917
# Epoch 11/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1337 - acc: 0.9582 - val_loss: 0.4672 - val_acc: 0.8186
# Epoch 12/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1085 - acc: 0.9664 - val_loss: 0.3843 - val_acc: 0.8689
# Epoch 13/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1044 - acc: 0.9649 - val_loss: 0.3446 - val_acc: 0.8880
# Epoch 14/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.1056 - acc: 0.9698 - val_loss: 0.2492 - val_acc: 0.9384
# Epoch 15/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0947 - acc: 0.9696 - val_loss: 0.2625 - val_acc: 0.8854
# Epoch 16/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0752 - acc: 0.9759 - val_loss: 0.3329 - val_acc: 0.8464
# Epoch 17/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0785 - acc: 0.9765 - val_loss: 0.0925 - val_acc: 0.9592
# Epoch 18/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0780 - acc: 0.9780 - val_loss: 0.4552 - val_acc: 0.8203
# Epoch 19/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0772 - acc: 0.9765 - val_loss: 0.1597 - val_acc: 0.9271
# Epoch 20/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0590 - acc: 0.9808 - val_loss: 0.2144 - val_acc: 0.9193
# Epoch 21/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0629 - acc: 0.9804 - val_loss: 0.1714 - val_acc: 0.9253
# Epoch 22/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0617 - acc: 0.9816 - val_loss: 0.1216 - val_acc: 0.9549
# Epoch 23/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0485 - acc: 0.9849 - val_loss: 0.1371 - val_acc: 0.9523
# Epoch 24/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0574 - acc: 0.9825 - val_loss: 0.1521 - val_acc: 0.9479
# Epoch 25/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0529 - acc: 0.9845 - val_loss: 0.2687 - val_acc: 0.8932
# Epoch 26/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0614 - acc: 0.9822 - val_loss: 0.1119 - val_acc: 0.9670
# Epoch 27/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0458 - acc: 0.9860 - val_loss: 0.4527 - val_acc: 0.8750
# Epoch 28/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0546 - acc: 0.9844 - val_loss: 0.0278 - val_acc: 0.9913
# Epoch 29/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0421 - acc: 0.9866 - val_loss: 0.3237 - val_acc: 0.8681
# Epoch 30/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0419 - acc: 0.9887 - val_loss: 0.0954 - val_acc: 0.9557
# Epoch 31/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0391 - acc: 0.9877 - val_loss: 0.0765 - val_acc: 0.9809
# Epoch 32/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0415 - acc: 0.9884 - val_loss: 0.0994 - val_acc: 0.9627
# Epoch 33/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0501 - acc: 0.9855 - val_loss: 0.1237 - val_acc: 0.9644
# Epoch 34/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0479 - acc: 0.9867 - val_loss: 0.1123 - val_acc: 0.9696
# Epoch 35/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0373 - acc: 0.9884 - val_loss: 0.4071 - val_acc: 0.9106
# Epoch 36/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0290 - acc: 0.9913 - val_loss: 0.0334 - val_acc: 0.9887
# Epoch 37/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0433 - acc: 0.9881 - val_loss: 0.0294 - val_acc: 0.9931
# Epoch 38/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0362 - acc: 0.9895 - val_loss: 0.0184 - val_acc: 0.9948
# Epoch 39/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0318 - acc: 0.9908 - val_loss: 0.0482 - val_acc: 0.9870
# Epoch 40/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0332 - acc: 0.9898 - val_loss: 0.1149 - val_acc: 0.9653
# Epoch 41/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0400 - acc: 0.9895 - val_loss: 0.0923 - val_acc: 0.9661
# Epoch 42/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0309 - acc: 0.9908 - val_loss: 0.0486 - val_acc: 0.9792
# Epoch 43/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0212 - acc: 0.9931 - val_loss: 0.0328 - val_acc: 0.9887
# Epoch 44/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0338 - acc: 0.9902 - val_loss: 0.0078 - val_acc: 0.9991
# Epoch 45/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0352 - acc: 0.9910 - val_loss: 0.0451 - val_acc: 0.9792
# Epoch 46/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0251 - acc: 0.9930 - val_loss: 0.0849 - val_acc: 0.9627
# Epoch 47/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0282 - acc: 0.9923 - val_loss: 0.0381 - val_acc: 0.9870
# Epoch 48/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0298 - acc: 0.9924 - val_loss: 0.0727 - val_acc: 0.9844
# Epoch 49/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0293 - acc: 0.9909 - val_loss: 0.0316 - val_acc: 0.9913
# Epoch 50/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0320 - acc: 0.9908 - val_loss: 0.0317 - val_acc: 0.9826
# Epoch 51/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0316 - acc: 0.9909 - val_loss: 0.0138 - val_acc: 0.9974
# Epoch 52/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0341 - acc: 0.9920 - val_loss: 0.0254 - val_acc: 0.9939
# Epoch 53/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0286 - acc: 0.9923 - val_loss: 0.1153 - val_acc: 0.9453
# Epoch 54/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0281 - acc: 0.9922 - val_loss: 0.0576 - val_acc: 0.9705
# Epoch 55/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0259 - acc: 0.9926 - val_loss: 0.0148 - val_acc: 0.9931
# Epoch 56/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0253 - acc: 0.9923 - val_loss: 0.0048 - val_acc: 0.9974
# Epoch 57/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0271 - acc: 0.9925 - val_loss: 0.0169 - val_acc: 0.9965
# Epoch 58/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0209 - acc: 0.9937 - val_loss: 0.0231 - val_acc: 0.9931
# Epoch 59/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0351 - acc: 0.9914 - val_loss: 0.0403 - val_acc: 0.9826
# Epoch 60/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0262 - acc: 0.9924 - val_loss: 0.0069 - val_acc: 0.9974
# Epoch 61/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0254 - acc: 0.9931 - val_loss: 0.0218 - val_acc: 0.9887
# Epoch 62/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0230 - acc: 0.9935 - val_loss: 0.2899 - val_acc: 0.9566
# Epoch 63/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0316 - acc: 0.9919 - val_loss: 0.0033 - val_acc: 0.9991
# Epoch 64/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0299 - acc: 0.9917 - val_loss: 9.0945e-04 - val_acc: 1.0000
# Epoch 65/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0205 - acc: 0.9946 - val_loss: 0.0789 - val_acc: 0.9748
# Epoch 66/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0224 - acc: 0.9937 - val_loss: 0.0342 - val_acc: 0.9861
# Epoch 67/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0238 - acc: 0.9937 - val_loss: 7.4803e-04 - val_acc: 1.0000
# Epoch 68/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0243 - acc: 0.9933 - val_loss: 0.0506 - val_acc: 0.9835
# Epoch 69/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0139 - acc: 0.9950 - val_loss: 0.0028 - val_acc: 0.9991
# Epoch 70/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0310 - acc: 0.9922 - val_loss: 0.0196 - val_acc: 0.9905
# Epoch 71/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0227 - acc: 0.9946 - val_loss: 0.0495 - val_acc: 0.9870
# Epoch 72/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0277 - acc: 0.9931 - val_loss: 0.0386 - val_acc: 0.9826
# Epoch 73/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0282 - acc: 0.9929 - val_loss: 0.0025 - val_acc: 1.0000
# Epoch 74/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0197 - acc: 0.9945 - val_loss: 0.0255 - val_acc: 0.9896
# Epoch 75/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0213 - acc: 0.9937 - val_loss: 0.0027 - val_acc: 0.9991
# Epoch 76/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0175 - acc: 0.9952 - val_loss: 0.0589 - val_acc: 0.9792
# Epoch 77/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0256 - acc: 0.9933 - val_loss: 0.0270 - val_acc: 0.9896
# Epoch 78/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0279 - acc: 0.9927 - val_loss: 0.0482 - val_acc: 0.9809
# Epoch 79/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0140 - acc: 0.9954 - val_loss: 0.1136 - val_acc: 0.9740
# Epoch 80/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0209 - acc: 0.9945 - val_loss: 0.0205 - val_acc: 0.9913
# Epoch 81/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0201 - acc: 0.9940 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 82/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0230 - acc: 0.9932 - val_loss: 0.0328 - val_acc: 0.9905
# Epoch 83/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0151 - acc: 0.9961 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 84/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0241 - acc: 0.9935 - val_loss: 0.0091 - val_acc: 0.9991
# Epoch 85/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0329 - acc: 0.9933 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 86/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0123 - acc: 0.9960 - val_loss: 6.4125e-04 - val_acc: 1.0000
# Epoch 87/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0241 - acc: 0.9931 - val_loss: 0.0274 - val_acc: 0.9887
# Epoch 88/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0136 - acc: 0.9958 - val_loss: 0.0086 - val_acc: 0.9957
# Epoch 89/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0208 - acc: 0.9951 - val_loss: 0.0085 - val_acc: 0.9965
# Epoch 90/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0238 - acc: 0.9940 - val_loss: 0.0201 - val_acc: 0.9887
# Epoch 91/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0166 - acc: 0.9960 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 92/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0246 - acc: 0.9936 - val_loss: 6.2580e-04 - val_acc: 1.0000
# Epoch 93/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0226 - acc: 0.9946 - val_loss: 0.0109 - val_acc: 0.9939
# Epoch 94/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0153 - acc: 0.9963 - val_loss: 0.0136 - val_acc: 0.9948
# Epoch 95/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0165 - acc: 0.9954 - val_loss: 0.1122 - val_acc: 0.9635
# Epoch 96/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0281 - acc: 0.9931 - val_loss: 0.0018 - val_acc: 0.9991
# Epoch 97/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0206 - acc: 0.9948 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 98/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0183 - acc: 0.9955 - val_loss: 0.0123 - val_acc: 0.9922
# Epoch 99/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0248 - acc: 0.9945 - val_loss: 0.0037 - val_acc: 0.9991
# Epoch 100/100
# 10360/10360 [==============================] - 49s 5ms/sample - loss: 0.0236 - acc: 0.9942 - val_loss: 0.0301 - val_acc: 0.9878

# %% [markdown]
# <h2>Evaluation (Basic)</h2>

# %%
## Loss and accuracy history
_, axs = plt.subplots(ncols=2)
df_history_info = pd.DataFrame(history_info) 


sns.lineplot(data=df_history_info['loss'],ax=axs[0], label='Training Loss', legend='brief')
sns.lineplot(data=df_history_info['val_loss'],ax=axs[0], label='Validation Loss', legend='brief')

sns.lineplot(data=df_history_info['acc'],ax=axs[1], label='Training Accuracy', legend='brief')
sns.lineplot(data=df_history_info['val_acc'],ax=axs[1], label='Validation Accuracy', legend='brief')

# %%
def generate_actual_predicted(Y_pred, X_test, Y_test): 
    predicted = list()
    for i in range(len(Y_pred)):
        predicted.append(np.argmax(Y_pred[i]))
        
    actual = list()
    for i in range(len(Y_test)):
        actual.append(np.argmax(Y_test[i]))
        
    return actual, predicted

# %%
Y_pred = model.predict(X_test)
actual, predicted = generate_actual_predicted(Y_pred, X_test, Y_test)

##Confusion Matrix
from sklearn.metrics import confusion_matrix
actual_labeled = list()
predict_labeled = list()
for x,y in zip(actual,predicted):
    actual_labeled.append(getSpecies(x))
    predict_labeled.append(getSpecies(y))

labels = ['A.tridens','E.bottae','M.emarginatus','P.kuhli','R.muscatellum','R.nasutus', 'R.aegyptius', 'T.perforatus']
cm=confusion_matrix(actual_labeled,predict_labeled,labels=labels)
print(cm)

ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labels,rotation=45); ax.yaxis.set_ticklabels(labels,rotation=45);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4158799836bf> in <module>
# ----> 1 Y_pred = model.predict(X_test)
#       2 actual, predicted = generate_actual_predicted(Y_pred, X_test, Y_test)
#       3
#       4 ##Confusion Matrix
#       5 from sklearn.metrics import confusion_matrix
#
# NameError: name 'X_test' is not defined

# %%
## Test accuracy
from sklearn.metrics import accuracy_score
print('accuracy', accuracy_score(actual, predicted))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-400d3a6cdf9a> in <module>
#       1 ## Test accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 print('accuracy', accuracy_score(actual, predicted))
#
# NameError: name 'actual' is not defined

# %%
## Precision, Recall, F1, Support
from sklearn.metrics import classification_report
print(classification_report(actual_labeled, predict_labeled,labels=labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9891608f9c62> in <module>
#       1 ## Precision, Recall, F1, Support
#       2 from sklearn.metrics import classification_report
# ----> 3 print(classification_report(actual_labeled, predict_labeled,labels=labels))
#
# NameError: name 'actual_labeled' is not defined

# %%
##ROC AUC Scores
from sklearn.metrics import roc_auc_score
print('One-vs-One ROC AUC scores:')
print(roc_auc_score(actual, Y_pred, average='macro', multi_class='ovo'), '(macro)')
print(roc_auc_score(actual, Y_pred, average='weighted', multi_class='ovo'), '(weighted by prevalence)')


print()
print('One-vs-Rest ROC AUC scores:')
print(roc_auc_score(actual, Y_pred, average='macro', multi_class='ovr'), '(macro)')
print(roc_auc_score(actual, Y_pred, average='weighted', multi_class='ovr'), '(weighted by prevalence)')
# Out:
# One-vs-One ROC AUC scores:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-bdd9b2b06663> in <module>
#       2 from sklearn.metrics import roc_auc_score
#       3 print('One-vs-One ROC AUC scores:')
# ----> 4 print(roc_auc_score(actual, Y_pred, average='macro', multi_class='ovo'), '(macro)')
#       5 print(roc_auc_score(actual, Y_pred, average='weighted', multi_class='ovo'), '(weighted by prevalence)')
#       6
#
# NameError: name 'actual' is not defined

# %%
## ROC Curves
from sklearn.metrics import roc_curve, auc
import seaborn as sns
from scipy import interp

### The following curves are generated s.t each point is a model from differing thresholds

### ROC Curves + AUC per class

_, axs = plt.subplots(ncols=1)
axs.set(xlabel='False Positive Rate',ylabel='True Positive Rate', title='ROC Curve')

fpr = [0] * 8
tpr = [0] * 8
for i in range(8):
    fpr[i], tpr[i], _ = roc_curve(Y_test[:,i], Y_pred[:,i])
    auc_val = auc(fpr[i], tpr[i])
    auc_val = np.around(auc_val,4)
    sns.lineplot(x=fpr[i],y=tpr[i],ax=axs, label='Class '+ getSpecies(i) +' (area = ' + str(auc_val) + ')', legend='brief')

#### Micro/Macro ROC Curves + AUC over all classes

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(8)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(8):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= 8

fpr_macro = all_fpr
tpr_macro = mean_tpr
roc_auc_macro = auc(fpr_macro, tpr_macro)
fpr_micro, tpr_micro,_ = roc_curve(Y_test.ravel(), Y_pred.ravel())
roc_auc_micro = auc(fpr_micro, tpr_micro)


roc_auc_macro = np.around(roc_auc_macro,4)
roc_auc_micro = np.around(roc_auc_micro,4)
sns.lineplot(x=fpr_macro,y=tpr_macro,ax=axs, label='Macro-average ROC curve (area = ' + str(roc_auc_macro) + ')', legend='brief')
sns.lineplot(x=fpr_micro,y=tpr_micro,ax=axs, label='Micro-average ROC curve (area = ' + str(roc_auc_micro) + ')', legend='brief')

## Diagonal line for comparison
plt.plot([0, 1], [0, 1], 'k--', lw=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bf3ce79f83f5> in <module>
#      14 tpr = [0] * 8
#      15 for i in range(8):
# ---> 16     fpr[i], tpr[i], _ = roc_curve(Y_test[:,i], Y_pred[:,i])
#      17     auc_val = auc(fpr[i], tpr[i])
#      18     auc_val = np.around(auc_val,4)
#
# NameError: name 'Y_test' is not defined

# %%
## Precision/Recall Curves per class
### The following curves are generated s.t each point is a model from differing thresholds
from sklearn.metrics import precision_recall_curve

_, axs = plt.subplots(ncols=1)
axs.set(xlabel='Recall',ylabel='Precision', title='Precision/Recall Curve')

prec = [0] * 8
rec = [0] * 8
for i in range(8):
    prec[i], rec[i], _ = precision_recall_curve(Y_test[:,i], Y_pred[:,i])
    sns.lineplot(x=rec[i],y=prec[i],ax=axs, label='Class '+ getSpecies(i), legend='brief')

# Diagonal line for comparison
plt.plot([1, 0], [0, 1], 'k--', lw=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-749baadc1277> in <module>
#       9 rec = [0] * 8
#      10 for i in range(8):
# ---> 11     prec[i], rec[i], _ = precision_recall_curve(Y_test[:,i], Y_pred[:,i])
#      12     sns.lineplot(x=rec[i],y=prec[i],ax=axs, label='Class '+ getSpecies(i), legend='brief')
#      13
#
# NameError: name 'Y_test' is not defined

# %% [markdown]
# <h2>K-Fold Training and Evaluation</h2>

# %%
#Precision Mean and Standard Deviation
#Recall Mean and Standard Deviation
#F1 Measure Mean and Standard Deviation
#True Positive Rate. Mean and Standard Deviation
#False Negative Rate Mean and Standard Deviation
#Best/Worst ROC
#Best/Worst Precision/Recall
#Accuracy Mean and Standard Deviation

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix

all_base_precision = list()
all_base_recall = list()
all_macro_precision = list()
all_macro_recall = list()
all_f1 = list()
all_macro_f1 = list()


all_tpr = list()
all_fpr = list()
all_precision = list()
all_recall = list()
all_cm=list()
all_accuracy = list()


n_split=5
n_classes=8

y_all_labelled=[]
for i in range(len(Y_all)):
        y_all_labelled.append(np.argmax(Y_all[i]))
        
my_callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=20,verbose=1, mode='min',restore_best_weights=True)]
       
for train_index,test_index in StratifiedKFold(n_split).split(X_all,y_all_labelled):  
    # use the index to generate training an testing sets
    x_train,x_test=X_all[train_index],X_all[test_index]
    y_train,y_test=Y_all[train_index],Y_all[test_index]
    
    #oversample
    x_train, y_train= makeOverSamplesSMOTE(x_train, y_train)
       
    # create and fit the model
    cv_model=build_current_model() # lr,dense,cnn
    history = cv_model.fit(x_train, y_train,
              batch_size=8,
              epochs=100,
              validation_split=0.1,
              verbose=1,
            callbacks=my_callbacks)
    
    #generate predictions
    y_pred = cv_model.predict(x_test)
    actual, predicted = generate_actual_predicted(y_pred, x_test, y_test)
    
    #calc metrics
    curr_base_prec, curr_base_rec, curr_f1, _ = precision_recall_fscore_support(actual, predicted)
    curr_macro_prec = precision_score(actual, predicted,average='macro')
    curr_macro_rec = recall_score(actual, predicted,average='macro')
    curr_macro_f1 = f1_score(actual, predicted,average='macro')
    
    
    actual_labeled = list()
    predict_labeled = list()
    for x,y in zip(actual,predicted):
        actual_labeled.append(getSpecies(x))
        predict_labeled.append(getSpecies(y))
        
    labels = ['A.tridens','E.bottae','M.emarginatus','P.kuhli','R.muscatellum','R.nasutus', 'R.aegyptius', 'T.perforatus']
    curr_cm=confusion_matrix(actual_labeled,predict_labeled,labels=labels)
    
    curr_fpr = [0] * n_classes
    curr_tpr = [0] * n_classes
    for i in range(n_classes):
        curr_fpr[i], curr_tpr[i], _ = roc_curve(y_test[:,i], y_pred[:,i])
        
    curr_prec = [0] * n_classes
    curr_rec = [0] * n_classes
    for i in range(n_classes):
        curr_prec[i], curr_rec[i], _ = precision_recall_curve(y_test[:,i], y_pred[:,i])

        
    curr_accuracy = accuracy_score(actual, predicted)
    
    #add to lists
    all_base_precision.append(curr_base_prec)
    all_base_recall.append(curr_base_rec)
    all_macro_precision.append(curr_macro_prec)
    all_macro_recall.append(curr_macro_rec)
    
    all_f1.append(curr_f1)
    all_macro_f1.append(curr_macro_f1)
    
    all_accuracy.append(curr_accuracy)

    
    all_fpr.append(curr_fpr)
    all_tpr.append(curr_tpr)
    all_precision.append(curr_prec)
    all_recall.append(curr_rec)
    all_cm.append(curr_cm)
# Out:
# Original trainingset shape [('E.bottae', 99), ('R.muscatellum', 1332), ('P.kuhli', 240), ('R.nasutus', 215), ('T.perforatus', 322), ('M.emarginatus', 90), ('R.aegyptius', 96), ('A.tridens', 20)]
# Resampled training set shape [('E.bottae', 1332), ('R.muscatellum', 1332), ('P.kuhli', 1332), ('R.nasutus', 1332), ('T.perforatus', 1332), ('M.emarginatus', 1332), ('R.aegyptius', 1332), ('A.tridens', 1332)]
# After OverSampling
# X_train: shape=  (10656, 112, 170, 3)
# Y_train: shape=  (10656, 8)
# Train on 9590 samples, validate on 1066 samples
# Epoch 1/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 1.3040 - acc: 0.5656 - val_loss: 0.3579 - val_acc: 0.8874
# Epoch 2/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.7408 - acc: 0.7430 - val_loss: 2.5832 - val_acc: 0.2017
# Epoch 3/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.5407 - acc: 0.8172 - val_loss: 1.3700 - val_acc: 0.5844
# Epoch 4/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.4402 - acc: 0.8519 - val_loss: 0.6039 - val_acc: 0.8077
# Epoch 5/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.3456 - acc: 0.8850 - val_loss: 0.3744 - val_acc: 0.8480
# Epoch 6/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.3018 - acc: 0.9024 - val_loss: 1.1984 - val_acc: 0.5826
# Epoch 7/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.2584 - acc: 0.9142 - val_loss: 0.7225 - val_acc: 0.6839
# Epoch 8/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.2018 - acc: 0.9348 - val_loss: 0.7436 - val_acc: 0.7692
# Epoch 9/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.1919 - acc: 0.9398 - val_loss: 0.2144 - val_acc: 0.9240
# Epoch 10/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.1652 - acc: 0.9498 - val_loss: 0.1655 - val_acc: 0.9493
# Epoch 11/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.1322 - acc: 0.9586 - val_loss: 0.3315 - val_acc: 0.8677
# Epoch 12/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.1276 - acc: 0.9588 - val_loss: 0.3958 - val_acc: 0.8818
# Epoch 13/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.1212 - acc: 0.9630 - val_loss: 0.1982 - val_acc: 0.9334
# Epoch 14/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0921 - acc: 0.9712 - val_loss: 0.1369 - val_acc: 0.9390
# Epoch 15/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0978 - acc: 0.9713 - val_loss: 0.1342 - val_acc: 0.9475
# Epoch 16/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0890 - acc: 0.9758 - val_loss: 0.1447 - val_acc: 0.9278
# Epoch 17/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0934 - acc: 0.9730 - val_loss: 0.3440 - val_acc: 0.8386
# Epoch 18/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0791 - acc: 0.9769 - val_loss: 0.1506 - val_acc: 0.9428
# Epoch 19/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0670 - acc: 0.9797 - val_loss: 0.1432 - val_acc: 0.9250
# Epoch 20/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0745 - acc: 0.9773 - val_loss: 0.4928 - val_acc: 0.8143
# Epoch 21/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0621 - acc: 0.9800 - val_loss: 0.2749 - val_acc: 0.8846
# Epoch 22/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0552 - acc: 0.9826 - val_loss: 0.0569 - val_acc: 0.9765
# Epoch 23/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0560 - acc: 0.9835 - val_loss: 0.0682 - val_acc: 0.9812
# Epoch 24/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0474 - acc: 0.9851 - val_loss: 0.0382 - val_acc: 0.9906
# Epoch 25/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0675 - acc: 0.9814 - val_loss: 0.0525 - val_acc: 0.9869
# Epoch 26/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0449 - acc: 0.9868 - val_loss: 0.0760 - val_acc: 0.9700
# Epoch 27/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0533 - acc: 0.9842 - val_loss: 0.0468 - val_acc: 0.9934
# Epoch 28/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0489 - acc: 0.9871 - val_loss: 0.3209 - val_acc: 0.9353
# Epoch 29/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0480 - acc: 0.9863 - val_loss: 0.2758 - val_acc: 0.8977
# Epoch 30/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0441 - acc: 0.9873 - val_loss: 0.1832 - val_acc: 0.9475
# Epoch 31/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0425 - acc: 0.9893 - val_loss: 0.1950 - val_acc: 0.9522
# Epoch 32/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0382 - acc: 0.9889 - val_loss: 0.0133 - val_acc: 0.9962
# Epoch 33/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0479 - acc: 0.9872 - val_loss: 0.4107 - val_acc: 0.9099
# Epoch 34/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0327 - acc: 0.9899 - val_loss: 0.0999 - val_acc: 0.9606
# Epoch 35/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0503 - acc: 0.9862 - val_loss: 0.0603 - val_acc: 0.9747
# Epoch 36/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0298 - acc: 0.9919 - val_loss: 0.0443 - val_acc: 0.9859
# Epoch 37/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0376 - acc: 0.9886 - val_loss: 0.0722 - val_acc: 0.9747
# Epoch 38/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0441 - acc: 0.9887 - val_loss: 0.0248 - val_acc: 0.9925
# Epoch 39/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0318 - acc: 0.9908 - val_loss: 0.0476 - val_acc: 0.9803
# Epoch 40/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0415 - acc: 0.9892 - val_loss: 0.0441 - val_acc: 0.9869
# Epoch 41/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0302 - acc: 0.9917 - val_loss: 0.0496 - val_acc: 0.9794
# Epoch 42/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0346 - acc: 0.9901 - val_loss: 0.0286 - val_acc: 0.9916
# Epoch 43/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0293 - acc: 0.9920 - val_loss: 0.0482 - val_acc: 0.9784
# Epoch 44/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0290 - acc: 0.9911 - val_loss: 0.0146 - val_acc: 0.9953
# Epoch 45/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0403 - acc: 0.9896 - val_loss: 0.0389 - val_acc: 0.9887
# Epoch 46/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0365 - acc: 0.9901 - val_loss: 0.0375 - val_acc: 0.9869
# Epoch 47/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0290 - acc: 0.9922 - val_loss: 0.0275 - val_acc: 0.9916
# Epoch 48/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0311 - acc: 0.9916 - val_loss: 0.1056 - val_acc: 0.9709
# Epoch 49/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0317 - acc: 0.9910 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 50/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0263 - acc: 0.9914 - val_loss: 0.0051 - val_acc: 0.9991
# Epoch 51/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0229 - acc: 0.9932 - val_loss: 0.0124 - val_acc: 0.9981
# Epoch 52/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0422 - acc: 0.9900 - val_loss: 0.1076 - val_acc: 0.9728
# Epoch 53/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0194 - acc: 0.9946 - val_loss: 0.0483 - val_acc: 0.9690
# Epoch 54/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0377 - acc: 0.9908 - val_loss: 0.1690 - val_acc: 0.9456
# Epoch 55/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0178 - acc: 0.9949 - val_loss: 0.0392 - val_acc: 0.9869
# Epoch 56/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0319 - acc: 0.9917 - val_loss: 0.0470 - val_acc: 0.9822
# Epoch 57/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0307 - acc: 0.9925 - val_loss: 0.1552 - val_acc: 0.9418
# Epoch 58/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0223 - acc: 0.9931 - val_loss: 0.0047 - val_acc: 0.9991
# Epoch 59/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0247 - acc: 0.9933 - val_loss: 0.0257 - val_acc: 0.9953
# Epoch 60/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0302 - acc: 0.9924 - val_loss: 0.0198 - val_acc: 0.9953
# Epoch 61/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0264 - acc: 0.9929 - val_loss: 0.4729 - val_acc: 0.8762
# Epoch 62/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0242 - acc: 0.9936 - val_loss: 0.2317 - val_acc: 0.9259
# Epoch 63/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0217 - acc: 0.9934 - val_loss: 0.0706 - val_acc: 0.9859
# Epoch 64/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0248 - acc: 0.9943 - val_loss: 0.0732 - val_acc: 0.9803
# Epoch 65/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0261 - acc: 0.9937 - val_loss: 0.1113 - val_acc: 0.9606
# Epoch 66/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0284 - acc: 0.9936 - val_loss: 0.0168 - val_acc: 0.9944
# Epoch 67/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0234 - acc: 0.9938 - val_loss: 0.1410 - val_acc: 0.9672
# Epoch 68/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0297 - acc: 0.9930 - val_loss: 0.0326 - val_acc: 0.9869
# Epoch 69/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0296 - acc: 0.9918 - val_loss: 0.0121 - val_acc: 1.0000
# Epoch 70/100
# 9590/9590 [==============================] - 23s 2ms/sample - loss: 0.0165 - acc: 0.9956 - val_loss: 0.0049 - val_acc: 0.9981
# Epoch 71/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0244 - acc: 0.9950 - val_loss: 0.0122 - val_acc: 0.9944
# Epoch 72/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0161 - acc: 0.9953 - val_loss: 0.0484 - val_acc: 0.9841
# Epoch 73/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0244 - acc: 0.9938 - val_loss: 0.0111 - val_acc: 0.9972
# Epoch 74/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0274 - acc: 0.9932 - val_loss: 0.0232 - val_acc: 0.9934
# Epoch 75/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0152 - acc: 0.9972 - val_loss: 0.1499 - val_acc: 0.9315
# Epoch 76/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0270 - acc: 0.9930 - val_loss: 0.0624 - val_acc: 0.9728
# Epoch 77/100
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0190 - acc: 0.9950 - val_loss: 0.2815 - val_acc: 0.9325
# Epoch 78/100
# 9568/9590 [============================>.] - ETA: 0s - loss: 0.0172 - acc: 0.9949Restoring model weights from the end of the best epoch.
# 9590/9590 [==============================] - 22s 2ms/sample - loss: 0.0172 - acc: 0.9949 - val_loss: 0.0220 - val_acc: 0.9916
# Epoch 00078: early stopping
# Original trainingset shape [('T.perforatus', 322), ('R.muscatellum', 1332), ('E.bottae', 99), ('R.nasutus', 216), ('P.kuhli', 239), ('R.aegyptius', 97), ('M.emarginatus', 89), ('A.tridens', 20)]
# Resampled training set shape [('T.perforatus', 1332), ('R.muscatellum', 1332), ('E.bottae', 1332), ('R.nasutus', 1332), ('P.kuhli', 1332), ('R.aegyptius', 1332), ('M.emarginatus', 1332), ('A.tridens', 1332)]
# After OverSampling
# X_train: shape=  (10656, 112, 170, 3)
# Y_train: shape=  (10656, 8)
# Train on 9590 samples, validate on 1066 samples
# Epoch 1/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 1.2457 - acc: 0.5725 - val_loss: 2.6712 - val_acc: 0.2317
# Epoch 2/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.7218 - acc: 0.7461 - val_loss: 0.7104 - val_acc: 0.7073
# Epoch 3/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.5256 - acc: 0.8240 - val_loss: 0.9374 - val_acc: 0.6660
# Epoch 4/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.4221 - acc: 0.8566 - val_loss: 0.4237 - val_acc: 0.8527
# Epoch 5/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.3255 - acc: 0.8943 - val_loss: 0.5239 - val_acc: 0.8236
# Epoch 6/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2796 - acc: 0.9103 - val_loss: 0.3518 - val_acc: 0.8771
# Epoch 7/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2233 - acc: 0.9281 - val_loss: 0.5505 - val_acc: 0.7936
# Epoch 8/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2070 - acc: 0.9347 - val_loss: 0.4530 - val_acc: 0.8659
# Epoch 9/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1733 - acc: 0.9464 - val_loss: 0.1763 - val_acc: 0.9287
# Epoch 10/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1617 - acc: 0.9529 - val_loss: 0.4090 - val_acc: 0.8302
# Epoch 11/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1243 - acc: 0.9621 - val_loss: 0.2242 - val_acc: 0.9081
# Epoch 12/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1362 - acc: 0.9587 - val_loss: 0.6873 - val_acc: 0.8096
# Epoch 13/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1073 - acc: 0.9673 - val_loss: 0.0992 - val_acc: 0.9653
# Epoch 14/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0980 - acc: 0.9700 - val_loss: 0.7945 - val_acc: 0.7664
# Epoch 15/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0960 - acc: 0.9707 - val_loss: 0.2873 - val_acc: 0.8921
# Epoch 16/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0912 - acc: 0.9728 - val_loss: 0.1432 - val_acc: 0.9653
# Epoch 17/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0885 - acc: 0.9749 - val_loss: 0.6788 - val_acc: 0.7214
# Epoch 18/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0875 - acc: 0.9758 - val_loss: 0.9786 - val_acc: 0.6041
# Epoch 19/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0635 - acc: 0.9789 - val_loss: 0.1525 - val_acc: 0.9371
# Epoch 20/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0625 - acc: 0.9804 - val_loss: 0.3545 - val_acc: 0.8311
# Epoch 21/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0708 - acc: 0.9804 - val_loss: 0.0896 - val_acc: 0.9540
# Epoch 22/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0588 - acc: 0.9836 - val_loss: 0.0660 - val_acc: 0.9765
# Epoch 23/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0564 - acc: 0.9827 - val_loss: 0.9069 - val_acc: 0.7495
# Epoch 24/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0702 - acc: 0.9786 - val_loss: 0.0387 - val_acc: 0.9925
# Epoch 25/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0540 - acc: 0.9846 - val_loss: 0.1663 - val_acc: 0.9381
# Epoch 26/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0508 - acc: 0.9832 - val_loss: 0.1200 - val_acc: 0.9587
# Epoch 27/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0463 - acc: 0.9853 - val_loss: 0.4150 - val_acc: 0.8668
# Epoch 28/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0500 - acc: 0.9851 - val_loss: 0.1086 - val_acc: 0.9615
# Epoch 29/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0453 - acc: 0.9876 - val_loss: 0.0512 - val_acc: 0.9794
# Epoch 30/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0578 - acc: 0.9821 - val_loss: 0.1195 - val_acc: 0.9465
# Epoch 31/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0465 - acc: 0.9860 - val_loss: 0.0598 - val_acc: 0.9775
# Epoch 32/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0416 - acc: 0.9880 - val_loss: 0.0711 - val_acc: 0.9794
# Epoch 33/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0329 - acc: 0.9892 - val_loss: 0.0858 - val_acc: 0.9700
# Epoch 34/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0482 - acc: 0.9867 - val_loss: 0.0167 - val_acc: 0.9953
# Epoch 35/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0382 - acc: 0.9887 - val_loss: 0.1218 - val_acc: 0.9559
# Epoch 36/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0442 - acc: 0.9868 - val_loss: 0.1352 - val_acc: 0.9306
# Epoch 37/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0300 - acc: 0.9921 - val_loss: 0.0451 - val_acc: 0.9831
# Epoch 38/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0360 - acc: 0.9893 - val_loss: 0.1652 - val_acc: 0.9644
# Epoch 39/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0467 - acc: 0.9872 - val_loss: 0.0262 - val_acc: 0.9934
# Epoch 40/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0369 - acc: 0.9903 - val_loss: 0.4109 - val_acc: 0.8443
# Epoch 41/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0319 - acc: 0.9907 - val_loss: 0.0431 - val_acc: 0.9869
# Epoch 42/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0419 - acc: 0.9895 - val_loss: 0.0417 - val_acc: 0.9831
# Epoch 43/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0247 - acc: 0.9917 - val_loss: 0.0405 - val_acc: 0.9822
# Epoch 44/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0397 - acc: 0.9894 - val_loss: 0.0503 - val_acc: 0.9803
# Epoch 45/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0376 - acc: 0.9900 - val_loss: 0.1063 - val_acc: 0.9578
# Epoch 46/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0325 - acc: 0.9907 - val_loss: 0.0904 - val_acc: 0.9625
# Epoch 47/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0243 - acc: 0.9940 - val_loss: 0.1298 - val_acc: 0.9456
# Epoch 48/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0377 - acc: 0.9897 - val_loss: 0.0147 - val_acc: 0.9953
# Epoch 49/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0183 - acc: 0.9948 - val_loss: 0.0517 - val_acc: 0.9803
# Epoch 50/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0325 - acc: 0.9924 - val_loss: 0.2524 - val_acc: 0.8987
# Epoch 51/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0422 - acc: 0.9885 - val_loss: 0.1591 - val_acc: 0.9447
# Epoch 52/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0229 - acc: 0.9935 - val_loss: 0.0234 - val_acc: 0.9944
# Epoch 53/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0296 - acc: 0.9921 - val_loss: 0.1181 - val_acc: 0.9644
# Epoch 54/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0211 - acc: 0.9938 - val_loss: 0.0055 - val_acc: 0.9981
# Epoch 55/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0261 - acc: 0.9917 - val_loss: 0.0140 - val_acc: 0.9934
# Epoch 56/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0272 - acc: 0.9929 - val_loss: 0.0286 - val_acc: 0.9887
# Epoch 57/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0332 - acc: 0.9919 - val_loss: 0.0154 - val_acc: 0.9962
# Epoch 58/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0277 - acc: 0.9935 - val_loss: 0.0121 - val_acc: 0.9981
# Epoch 59/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0345 - acc: 0.9916 - val_loss: 0.0372 - val_acc: 0.9850
# Epoch 60/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0213 - acc: 0.9945 - val_loss: 0.1635 - val_acc: 0.9512
# Epoch 61/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0328 - acc: 0.9918 - val_loss: 0.1614 - val_acc: 0.9381
# Epoch 62/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0231 - acc: 0.9940 - val_loss: 0.0710 - val_acc: 0.9709
# Epoch 63/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0244 - acc: 0.9934 - val_loss: 0.0212 - val_acc: 0.9953
# Epoch 64/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0200 - acc: 0.9941 - val_loss: 0.0038 - val_acc: 0.9981
# Epoch 65/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0315 - acc: 0.9917 - val_loss: 0.0792 - val_acc: 0.9756
# Epoch 66/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0272 - acc: 0.9938 - val_loss: 0.0746 - val_acc: 0.9728
# Epoch 67/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0223 - acc: 0.9938 - val_loss: 0.0921 - val_acc: 0.9709
# Epoch 68/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0305 - acc: 0.9910 - val_loss: 0.1000 - val_acc: 0.9597
# Epoch 69/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0204 - acc: 0.9943 - val_loss: 0.0403 - val_acc: 0.9841
# Epoch 70/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0216 - acc: 0.9944 - val_loss: 0.1433 - val_acc: 0.9522
# Epoch 71/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0189 - acc: 0.9953 - val_loss: 0.0082 - val_acc: 0.9981
# Epoch 72/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0268 - acc: 0.9942 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 73/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0270 - acc: 0.9941 - val_loss: 0.0098 - val_acc: 0.9991
# Epoch 74/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0262 - acc: 0.9937 - val_loss: 0.0395 - val_acc: 0.9831
# Epoch 75/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0172 - acc: 0.9956 - val_loss: 0.1297 - val_acc: 0.9690
# Epoch 76/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0213 - acc: 0.9946 - val_loss: 0.1236 - val_acc: 0.9634
# Epoch 77/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0297 - acc: 0.9930 - val_loss: 0.0148 - val_acc: 0.9944
# Epoch 78/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0182 - acc: 0.9957 - val_loss: 0.1062 - val_acc: 0.9747
# Epoch 79/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0230 - acc: 0.9944 - val_loss: 0.0176 - val_acc: 0.9916
# Epoch 80/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0261 - acc: 0.9927 - val_loss: 0.1093 - val_acc: 0.9709
# Epoch 81/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0238 - acc: 0.9933 - val_loss: 0.0293 - val_acc: 0.9916
# Epoch 82/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0238 - acc: 0.9954 - val_loss: 0.0356 - val_acc: 0.9906
# Epoch 83/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0211 - acc: 0.9942 - val_loss: 0.0145 - val_acc: 0.9953
# Epoch 84/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0192 - acc: 0.9940 - val_loss: 0.0089 - val_acc: 0.9962
# Epoch 85/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0233 - acc: 0.9942 - val_loss: 0.0285 - val_acc: 0.9887
# Epoch 86/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0224 - acc: 0.9947 - val_loss: 0.1120 - val_acc: 0.9775
# Epoch 87/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0219 - acc: 0.9948 - val_loss: 0.0557 - val_acc: 0.9775
# Epoch 88/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0182 - acc: 0.9956 - val_loss: 0.0035 - val_acc: 0.9991
# Epoch 89/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0269 - acc: 0.9925 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 90/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0205 - acc: 0.9943 - val_loss: 0.0271 - val_acc: 0.9887
# Epoch 91/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0201 - acc: 0.9942 - val_loss: 0.1908 - val_acc: 0.9381
# Epoch 92/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0253 - acc: 0.9931 - val_loss: 0.0480 - val_acc: 0.9803
# Epoch 93/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0159 - acc: 0.9957 - val_loss: 0.0127 - val_acc: 0.9953
# Epoch 94/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0174 - acc: 0.9958 - val_loss: 0.1103 - val_acc: 0.9672
# Epoch 95/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0181 - acc: 0.9957 - val_loss: 0.5212 - val_acc: 0.8827
# Epoch 96/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0201 - acc: 0.9962 - val_loss: 0.2262 - val_acc: 0.9437
# Epoch 97/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0143 - acc: 0.9966 - val_loss: 0.1502 - val_acc: 0.9428
# Epoch 98/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0153 - acc: 0.9965 - val_loss: 0.1775 - val_acc: 0.9493
# Epoch 99/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0219 - acc: 0.9944 - val_loss: 0.0137 - val_acc: 0.9972
# Epoch 100/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0177 - acc: 0.9953 - val_loss: 0.0508 - val_acc: 0.9784
# Original trainingset shape [('T.perforatus', 322), ('R.muscatellum', 1332), ('E.bottae', 100), ('R.nasutus', 215), ('P.kuhli', 239), ('R.aegyptius', 97), ('M.emarginatus', 89), ('A.tridens', 20)]
# Resampled training set shape [('T.perforatus', 1332), ('R.muscatellum', 1332), ('E.bottae', 1332), ('R.nasutus', 1332), ('P.kuhli', 1332), ('R.aegyptius', 1332), ('M.emarginatus', 1332), ('A.tridens', 1332)]
# After OverSampling
# X_train: shape=  (10656, 112, 170, 3)
# Y_train: shape=  (10656, 8)
# Train on 9590 samples, validate on 1066 samples
# Epoch 1/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 1.1831 - acc: 0.6058 - val_loss: 2.4126 - val_acc: 0.4128
# Epoch 2/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.7285 - acc: 0.7439 - val_loss: 1.7302 - val_acc: 0.2636
# Epoch 3/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.5464 - acc: 0.8077 - val_loss: 1.1619 - val_acc: 0.5629
# Epoch 4/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.4266 - acc: 0.8544 - val_loss: 1.6041 - val_acc: 0.6144
# Epoch 5/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.3752 - acc: 0.8705 - val_loss: 0.2519 - val_acc: 0.9259
# Epoch 6/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2897 - acc: 0.9033 - val_loss: 2.2885 - val_acc: 0.4512
# Epoch 7/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.2480 - acc: 0.9202 - val_loss: 0.6881 - val_acc: 0.7195
# Epoch 8/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2188 - acc: 0.9295 - val_loss: 0.5969 - val_acc: 0.7326
# Epoch 9/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1771 - acc: 0.9433 - val_loss: 0.7648 - val_acc: 0.7636
# Epoch 10/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1702 - acc: 0.9495 - val_loss: 0.2940 - val_acc: 0.8743
# Epoch 11/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1525 - acc: 0.9555 - val_loss: 0.0380 - val_acc: 0.9859
# Epoch 12/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1272 - acc: 0.9616 - val_loss: 1.3339 - val_acc: 0.6426
# Epoch 13/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1159 - acc: 0.9635 - val_loss: 0.0562 - val_acc: 0.9803
# Epoch 14/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1019 - acc: 0.9674 - val_loss: 0.2993 - val_acc: 0.8893
# Epoch 15/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0936 - acc: 0.9731 - val_loss: 0.3088 - val_acc: 0.8752
# Epoch 16/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0887 - acc: 0.9706 - val_loss: 0.1306 - val_acc: 0.9493
# Epoch 17/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0780 - acc: 0.9758 - val_loss: 0.1227 - val_acc: 0.9578
# Epoch 18/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0811 - acc: 0.9773 - val_loss: 0.0972 - val_acc: 0.9634
# Epoch 19/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0639 - acc: 0.9815 - val_loss: 0.3491 - val_acc: 0.8386
# Epoch 20/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0694 - acc: 0.9800 - val_loss: 0.5670 - val_acc: 0.7871
# Epoch 21/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0762 - acc: 0.9791 - val_loss: 0.1500 - val_acc: 0.9400
# Epoch 22/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0661 - acc: 0.9801 - val_loss: 0.0295 - val_acc: 0.9906
# Epoch 23/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0690 - acc: 0.9797 - val_loss: 0.3988 - val_acc: 0.8508
# Epoch 24/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0483 - acc: 0.9861 - val_loss: 0.1213 - val_acc: 0.9606
# Epoch 25/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0488 - acc: 0.9850 - val_loss: 0.0589 - val_acc: 0.9822
# Epoch 26/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0501 - acc: 0.9850 - val_loss: 0.1090 - val_acc: 0.9578
# Epoch 27/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0527 - acc: 0.9844 - val_loss: 0.1771 - val_acc: 0.9325
# Epoch 28/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0501 - acc: 0.9844 - val_loss: 0.1353 - val_acc: 0.9475
# Epoch 29/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0518 - acc: 0.9846 - val_loss: 0.0545 - val_acc: 0.9812
# Epoch 30/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0401 - acc: 0.9886 - val_loss: 0.1555 - val_acc: 0.9418
# Epoch 31/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0488 - acc: 0.9860 - val_loss: 0.1209 - val_acc: 0.9456
# Epoch 32/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0477 - acc: 0.9860 - val_loss: 0.0149 - val_acc: 0.9991
# Epoch 33/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0401 - acc: 0.9881 - val_loss: 0.0462 - val_acc: 0.9850
# Epoch 34/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0346 - acc: 0.9901 - val_loss: 0.1036 - val_acc: 0.9597
# Epoch 35/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0439 - acc: 0.9878 - val_loss: 0.0576 - val_acc: 0.9803
# Epoch 36/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0451 - acc: 0.9895 - val_loss: 0.0563 - val_acc: 0.9794
# Epoch 37/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0372 - acc: 0.9899 - val_loss: 0.1835 - val_acc: 0.9278
# Epoch 38/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0350 - acc: 0.9902 - val_loss: 0.0823 - val_acc: 0.9672
# Epoch 39/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0386 - acc: 0.9899 - val_loss: 0.0367 - val_acc: 0.9859
# Epoch 40/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0402 - acc: 0.9896 - val_loss: 0.0283 - val_acc: 0.9887
# Epoch 41/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0343 - acc: 0.9891 - val_loss: 0.0574 - val_acc: 0.9794
# Epoch 42/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0342 - acc: 0.9906 - val_loss: 0.1718 - val_acc: 0.9259
# Epoch 43/100
# 9590/9590 [==============================] - 19s 2ms/sample - loss: 0.0330 - acc: 0.9906 - val_loss: 0.0190 - val_acc: 0.9934
# Epoch 44/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0308 - acc: 0.9919 - val_loss: 0.0924 - val_acc: 0.9700
# Epoch 45/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0306 - acc: 0.9912 - val_loss: 1.5253 - val_acc: 0.8818
# Epoch 46/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0369 - acc: 0.9905 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 47/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0269 - acc: 0.9928 - val_loss: 0.0652 - val_acc: 0.9775
# Epoch 48/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0288 - acc: 0.9926 - val_loss: 0.2434 - val_acc: 0.9353
# Epoch 49/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0295 - acc: 0.9912 - val_loss: 0.1108 - val_acc: 0.9606
# Epoch 50/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0401 - acc: 0.9886 - val_loss: 0.0144 - val_acc: 0.9962
# Epoch 51/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0269 - acc: 0.9926 - val_loss: 0.0261 - val_acc: 0.9925
# Epoch 52/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0360 - acc: 0.9897 - val_loss: 0.2490 - val_acc: 0.9259
# Epoch 53/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0267 - acc: 0.9926 - val_loss: 0.3060 - val_acc: 0.9371
# Epoch 54/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0325 - acc: 0.9912 - val_loss: 0.0414 - val_acc: 0.9831
# Epoch 55/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0311 - acc: 0.9918 - val_loss: 0.0773 - val_acc: 0.9672
# Epoch 56/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0212 - acc: 0.9932 - val_loss: 0.0073 - val_acc: 0.9981
# Epoch 57/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0222 - acc: 0.9938 - val_loss: 0.0182 - val_acc: 0.9916
# Epoch 58/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0208 - acc: 0.9951 - val_loss: 0.0083 - val_acc: 0.9981
# Epoch 59/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0328 - acc: 0.9907 - val_loss: 0.0119 - val_acc: 0.9962
# Epoch 60/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0279 - acc: 0.9941 - val_loss: 0.0184 - val_acc: 0.9953
# Epoch 61/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0229 - acc: 0.9931 - val_loss: 0.0149 - val_acc: 0.9962
# Epoch 62/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0289 - acc: 0.9924 - val_loss: 0.0290 - val_acc: 0.9916
# Epoch 63/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0218 - acc: 0.9932 - val_loss: 0.0574 - val_acc: 0.9803
# Epoch 64/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0149 - acc: 0.9952 - val_loss: 0.0397 - val_acc: 0.9841
# Epoch 65/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0325 - acc: 0.9917 - val_loss: 0.0141 - val_acc: 0.9953
# Epoch 66/100
# 9584/9590 [============================>.] - ETA: 0s - loss: 0.0211 - acc: 0.9930Restoring model weights from the end of the best epoch.
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0212 - acc: 0.9929 - val_loss: 0.0378 - val_acc: 0.9906
# Epoch 00066: early stopping
# Original trainingset shape [('T.perforatus', 323), ('R.muscatellum', 1332), ('E.bottae', 99), ('R.nasutus', 215), ('P.kuhli', 239), ('R.aegyptius', 97), ('M.emarginatus', 90), ('A.tridens', 20)]
# Resampled training set shape [('T.perforatus', 1332), ('R.muscatellum', 1332), ('E.bottae', 1332), ('R.nasutus', 1332), ('P.kuhli', 1332), ('R.aegyptius', 1332), ('M.emarginatus', 1332), ('A.tridens', 1332)]
# After OverSampling
# X_train: shape=  (10656, 112, 170, 3)
# Y_train: shape=  (10656, 8)
# Train on 9590 samples, validate on 1066 samples
# Epoch 1/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 1.3384 - acc: 0.5477 - val_loss: 4.2315 - val_acc: 0.0544
# Epoch 2/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.7440 - acc: 0.7388 - val_loss: 1.8281 - val_acc: 0.3846
# Epoch 3/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.5742 - acc: 0.7948 - val_loss: 3.0480 - val_acc: 0.2383
# Epoch 4/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.4531 - acc: 0.8457 - val_loss: 1.2131 - val_acc: 0.5638
# Epoch 5/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.3745 - acc: 0.8707 - val_loss: 0.4002 - val_acc: 0.9006
# Epoch 6/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.3142 - acc: 0.8964 - val_loss: 0.7811 - val_acc: 0.7730
# Epoch 7/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2740 - acc: 0.9107 - val_loss: 0.9733 - val_acc: 0.6876
# Epoch 8/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2319 - acc: 0.9278 - val_loss: 0.3753 - val_acc: 0.8227
# Epoch 9/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2077 - acc: 0.9311 - val_loss: 0.2273 - val_acc: 0.9184
# Epoch 10/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.1691 - acc: 0.9463 - val_loss: 0.6219 - val_acc: 0.7720
# Epoch 11/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1401 - acc: 0.9552 - val_loss: 0.3819 - val_acc: 0.8574
# Epoch 12/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.1373 - acc: 0.9564 - val_loss: 0.4473 - val_acc: 0.8499
# Epoch 13/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1351 - acc: 0.9592 - val_loss: 0.1210 - val_acc: 0.9615
# Epoch 14/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1037 - acc: 0.9693 - val_loss: 0.1751 - val_acc: 0.9268
# Epoch 15/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1087 - acc: 0.9679 - val_loss: 0.3362 - val_acc: 0.8583
# Epoch 16/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0966 - acc: 0.9710 - val_loss: 0.5697 - val_acc: 0.8218
# Epoch 17/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0883 - acc: 0.9743 - val_loss: 0.4062 - val_acc: 0.8827
# Epoch 18/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0856 - acc: 0.9739 - val_loss: 0.0467 - val_acc: 0.9794
# Epoch 19/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0800 - acc: 0.9753 - val_loss: 0.2316 - val_acc: 0.9268
# Epoch 20/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0799 - acc: 0.9750 - val_loss: 0.0952 - val_acc: 0.9803
# Epoch 21/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0720 - acc: 0.9773 - val_loss: 0.3154 - val_acc: 0.8893
# Epoch 22/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0729 - acc: 0.9780 - val_loss: 0.3610 - val_acc: 0.8602
# Epoch 23/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0726 - acc: 0.9794 - val_loss: 0.0967 - val_acc: 0.9775
# Epoch 24/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0616 - acc: 0.9820 - val_loss: 0.3029 - val_acc: 0.9062
# Epoch 25/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0550 - acc: 0.9837 - val_loss: 0.1225 - val_acc: 0.9625
# Epoch 26/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0644 - acc: 0.9805 - val_loss: 0.3062 - val_acc: 0.8865
# Epoch 27/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0555 - acc: 0.9838 - val_loss: 0.1586 - val_acc: 0.9315
# Epoch 28/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0600 - acc: 0.9830 - val_loss: 0.0354 - val_acc: 0.9972
# Epoch 29/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0439 - acc: 0.9862 - val_loss: 0.1463 - val_acc: 0.9278
# Epoch 30/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0567 - acc: 0.9850 - val_loss: 0.3573 - val_acc: 0.8583
# Epoch 31/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0474 - acc: 0.9870 - val_loss: 0.1069 - val_acc: 0.9512
# Epoch 32/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0404 - acc: 0.9872 - val_loss: 0.2148 - val_acc: 0.9053
# Epoch 33/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0485 - acc: 0.9864 - val_loss: 0.1835 - val_acc: 0.9259
# Epoch 34/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0478 - acc: 0.9862 - val_loss: 0.1016 - val_acc: 0.9437
# Epoch 35/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0380 - acc: 0.9885 - val_loss: 0.1843 - val_acc: 0.9484
# Epoch 36/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0456 - acc: 0.9876 - val_loss: 0.0212 - val_acc: 0.9953
# Epoch 37/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0363 - acc: 0.9893 - val_loss: 0.0463 - val_acc: 0.9859
# Epoch 38/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0477 - acc: 0.9857 - val_loss: 0.1205 - val_acc: 0.9587
# Epoch 39/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0378 - acc: 0.9900 - val_loss: 0.4767 - val_acc: 0.9400
# Epoch 40/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0370 - acc: 0.9909 - val_loss: 0.0922 - val_acc: 0.9559
# Epoch 41/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0311 - acc: 0.9904 - val_loss: 0.1239 - val_acc: 0.9681
# Epoch 42/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0457 - acc: 0.9870 - val_loss: 0.0591 - val_acc: 0.9728
# Epoch 43/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0263 - acc: 0.9916 - val_loss: 0.1743 - val_acc: 0.9493
# Epoch 44/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0329 - acc: 0.9917 - val_loss: 0.3251 - val_acc: 0.9081
# Epoch 45/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0427 - acc: 0.9875 - val_loss: 0.0358 - val_acc: 0.9887
# Epoch 46/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0262 - acc: 0.9924 - val_loss: 0.0617 - val_acc: 0.9700
# Epoch 47/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0354 - acc: 0.9909 - val_loss: 0.0615 - val_acc: 0.9803
# Epoch 48/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0367 - acc: 0.9894 - val_loss: 0.3999 - val_acc: 0.9231
# Epoch 49/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0325 - acc: 0.9922 - val_loss: 0.0665 - val_acc: 0.9794
# Epoch 50/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0309 - acc: 0.9914 - val_loss: 0.0140 - val_acc: 0.9934
# Epoch 51/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0296 - acc: 0.9912 - val_loss: 0.7966 - val_acc: 0.7852
# Epoch 52/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0258 - acc: 0.9925 - val_loss: 0.0069 - val_acc: 0.9981
# Epoch 53/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0374 - acc: 0.9905 - val_loss: 0.0106 - val_acc: 0.9972
# Epoch 54/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0332 - acc: 0.9917 - val_loss: 0.0444 - val_acc: 0.9859
# Epoch 55/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0235 - acc: 0.9940 - val_loss: 0.1205 - val_acc: 0.9662
# Epoch 56/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0276 - acc: 0.9925 - val_loss: 0.0284 - val_acc: 0.9897
# Epoch 57/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0309 - acc: 0.9916 - val_loss: 0.1666 - val_acc: 0.9353
# Epoch 58/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0301 - acc: 0.9923 - val_loss: 0.0429 - val_acc: 0.9850
# Epoch 59/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0314 - acc: 0.9917 - val_loss: 0.0304 - val_acc: 0.9887
# Epoch 60/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0255 - acc: 0.9924 - val_loss: 0.0718 - val_acc: 0.9747
# Epoch 61/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0254 - acc: 0.9935 - val_loss: 0.0153 - val_acc: 0.9981
# Epoch 62/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0249 - acc: 0.9930 - val_loss: 0.0379 - val_acc: 0.9878
# Epoch 63/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0241 - acc: 0.9940 - val_loss: 0.0116 - val_acc: 0.9972
# Epoch 64/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0214 - acc: 0.9940 - val_loss: 0.0189 - val_acc: 0.9962
# Epoch 65/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0246 - acc: 0.9929 - val_loss: 0.0305 - val_acc: 0.9887
# Epoch 66/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0265 - acc: 0.9922 - val_loss: 0.0114 - val_acc: 0.9981
# Epoch 67/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0215 - acc: 0.9936 - val_loss: 0.0139 - val_acc: 0.9934
# Epoch 68/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0352 - acc: 0.9914 - val_loss: 0.0061 - val_acc: 0.9981
# Epoch 69/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0287 - acc: 0.9927 - val_loss: 0.0132 - val_acc: 0.9953
# Epoch 70/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0265 - acc: 0.9944 - val_loss: 0.0051 - val_acc: 1.0000
# Epoch 71/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0203 - acc: 0.9943 - val_loss: 0.1417 - val_acc: 0.9662
# Epoch 72/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0289 - acc: 0.9928 - val_loss: 0.0422 - val_acc: 0.9831
# Epoch 73/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0220 - acc: 0.9951 - val_loss: 0.0374 - val_acc: 0.9850
# Epoch 74/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0229 - acc: 0.9950 - val_loss: 0.1559 - val_acc: 0.9315
# Epoch 75/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0194 - acc: 0.9951 - val_loss: 0.0170 - val_acc: 0.9944
# Epoch 76/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0272 - acc: 0.9932 - val_loss: 0.0176 - val_acc: 0.9934
# Epoch 77/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0245 - acc: 0.9932 - val_loss: 0.0214 - val_acc: 0.9944
# Epoch 78/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0134 - acc: 0.9969 - val_loss: 0.9116 - val_acc: 0.8452
# Epoch 79/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0327 - acc: 0.9925 - val_loss: 0.0715 - val_acc: 0.9794
# Epoch 80/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0149 - acc: 0.9957 - val_loss: 0.0293 - val_acc: 0.9841
# Epoch 81/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0235 - acc: 0.9948 - val_loss: 0.0494 - val_acc: 0.9794
# Epoch 82/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0166 - acc: 0.9955 - val_loss: 0.0474 - val_acc: 0.9841
# Epoch 83/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0225 - acc: 0.9935 - val_loss: 0.1169 - val_acc: 0.9475
# Epoch 84/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0186 - acc: 0.9948 - val_loss: 0.0315 - val_acc: 0.9887
# Epoch 85/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0217 - acc: 0.9947 - val_loss: 0.0257 - val_acc: 0.9906
# Epoch 86/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0155 - acc: 0.9954 - val_loss: 0.0088 - val_acc: 0.9972
# Epoch 87/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0256 - acc: 0.9931 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 88/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0116 - acc: 0.9964 - val_loss: 0.0315 - val_acc: 0.9878
# Epoch 89/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0212 - acc: 0.9944 - val_loss: 0.0200 - val_acc: 0.9897
# Epoch 90/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0157 - acc: 0.9950 - val_loss: 0.0050 - val_acc: 0.9991
# Epoch 91/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0150 - acc: 0.9960 - val_loss: 0.1552 - val_acc: 0.9522
# Epoch 92/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0227 - acc: 0.9937 - val_loss: 0.0379 - val_acc: 0.9850
# Epoch 93/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0170 - acc: 0.9948 - val_loss: 0.0429 - val_acc: 0.9859
# Epoch 94/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0224 - acc: 0.9947 - val_loss: 0.0518 - val_acc: 0.9841
# Epoch 95/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0170 - acc: 0.9958 - val_loss: 0.0249 - val_acc: 0.9850
# Epoch 96/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0248 - acc: 0.9936 - val_loss: 0.1029 - val_acc: 0.9625
# Epoch 97/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0151 - acc: 0.9954 - val_loss: 0.0292 - val_acc: 0.9850
# Epoch 98/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0171 - acc: 0.9957 - val_loss: 0.1220 - val_acc: 0.9690
# Epoch 99/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0186 - acc: 0.9946 - val_loss: 0.0039 - val_acc: 0.9981
# Epoch 100/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0216 - acc: 0.9952 - val_loss: 0.0613 - val_acc: 0.9784
# Original trainingset shape [('T.perforatus', 323), ('R.muscatellum', 1332), ('E.bottae', 99), ('R.nasutus', 215), ('P.kuhli', 239), ('R.aegyptius', 97), ('M.emarginatus', 90), ('A.tridens', 20)]
# Resampled training set shape [('T.perforatus', 1332), ('R.muscatellum', 1332), ('E.bottae', 1332), ('R.nasutus', 1332), ('P.kuhli', 1332), ('R.aegyptius', 1332), ('M.emarginatus', 1332), ('A.tridens', 1332)]
# After OverSampling
# X_train: shape=  (10656, 112, 170, 3)
# Y_train: shape=  (10656, 8)
# Train on 9590 samples, validate on 1066 samples
# Epoch 1/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 1.3152 - acc: 0.5658 - val_loss: 4.0471 - val_acc: 0.0478
# Epoch 2/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.7309 - acc: 0.7395 - val_loss: 2.1130 - val_acc: 0.2683
# Epoch 3/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.5314 - acc: 0.8124 - val_loss: 2.1391 - val_acc: 0.3799
# Epoch 4/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.4306 - acc: 0.8518 - val_loss: 0.4126 - val_acc: 0.8471
# Epoch 5/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.3502 - acc: 0.8847 - val_loss: 0.8040 - val_acc: 0.6510
# Epoch 6/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2904 - acc: 0.9075 - val_loss: 0.5174 - val_acc: 0.8133
# Epoch 7/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.2424 - acc: 0.9187 - val_loss: 0.5460 - val_acc: 0.8311
# Epoch 8/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.2066 - acc: 0.9327 - val_loss: 0.8801 - val_acc: 0.6276
# Epoch 9/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1768 - acc: 0.9455 - val_loss: 0.2424 - val_acc: 0.9043
# Epoch 10/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1537 - acc: 0.9522 - val_loss: 0.3148 - val_acc: 0.8752
# Epoch 11/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.1551 - acc: 0.9517 - val_loss: 0.2172 - val_acc: 0.9053
# Epoch 12/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1271 - acc: 0.9612 - val_loss: 0.1355 - val_acc: 0.9540
# Epoch 13/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1116 - acc: 0.9663 - val_loss: 0.1523 - val_acc: 0.9409
# Epoch 14/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.1167 - acc: 0.9648 - val_loss: 0.1432 - val_acc: 0.9353
# Epoch 15/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0902 - acc: 0.9724 - val_loss: 0.3846 - val_acc: 0.8687
# Epoch 16/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0984 - acc: 0.9716 - val_loss: 0.0349 - val_acc: 0.9859
# Epoch 17/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0877 - acc: 0.9727 - val_loss: 0.5490 - val_acc: 0.8490
# Epoch 18/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0901 - acc: 0.9750 - val_loss: 0.1879 - val_acc: 0.9174
# Epoch 19/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0741 - acc: 0.9777 - val_loss: 0.2132 - val_acc: 0.9118
# Epoch 20/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0764 - acc: 0.9761 - val_loss: 0.4376 - val_acc: 0.8677
# Epoch 21/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0576 - acc: 0.9832 - val_loss: 0.0835 - val_acc: 0.9662
# Epoch 22/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0670 - acc: 0.9797 - val_loss: 0.0373 - val_acc: 0.9897
# Epoch 23/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0721 - acc: 0.9802 - val_loss: 0.1482 - val_acc: 0.9381
# Epoch 24/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0666 - acc: 0.9810 - val_loss: 0.0846 - val_acc: 0.9737
# Epoch 25/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0445 - acc: 0.9871 - val_loss: 0.2795 - val_acc: 0.9250
# Epoch 26/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0600 - acc: 0.9822 - val_loss: 0.2630 - val_acc: 0.9231
# Epoch 27/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0604 - acc: 0.9847 - val_loss: 0.1186 - val_acc: 0.9381
# Epoch 28/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0510 - acc: 0.9851 - val_loss: 0.1485 - val_acc: 0.9522
# Epoch 29/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0452 - acc: 0.9868 - val_loss: 0.0219 - val_acc: 0.9925
# Epoch 30/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0466 - acc: 0.9868 - val_loss: 0.0222 - val_acc: 0.9953
# Epoch 31/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0412 - acc: 0.9876 - val_loss: 0.0917 - val_acc: 0.9625
# Epoch 32/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0383 - acc: 0.9882 - val_loss: 0.0879 - val_acc: 0.9719
# Epoch 33/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0573 - acc: 0.9837 - val_loss: 0.0725 - val_acc: 0.9728
# Epoch 34/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0392 - acc: 0.9884 - val_loss: 0.0721 - val_acc: 0.9681
# Epoch 35/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0349 - acc: 0.9904 - val_loss: 0.0618 - val_acc: 0.9747
# Epoch 36/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0444 - acc: 0.9896 - val_loss: 0.1980 - val_acc: 0.9174
# Epoch 37/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0500 - acc: 0.9856 - val_loss: 0.0078 - val_acc: 0.9991
# Epoch 38/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0352 - acc: 0.9904 - val_loss: 0.2058 - val_acc: 0.9493
# Epoch 39/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0373 - acc: 0.9899 - val_loss: 0.0654 - val_acc: 0.9634
# Epoch 40/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0372 - acc: 0.9911 - val_loss: 0.0177 - val_acc: 0.9934
# Epoch 41/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0375 - acc: 0.9887 - val_loss: 0.0845 - val_acc: 0.9822
# Epoch 42/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0365 - acc: 0.9894 - val_loss: 0.0954 - val_acc: 0.9615
# Epoch 43/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0364 - acc: 0.9899 - val_loss: 0.1487 - val_acc: 0.9503
# Epoch 44/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0382 - acc: 0.9898 - val_loss: 0.3025 - val_acc: 0.9034
# Epoch 45/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0227 - acc: 0.9933 - val_loss: 0.0475 - val_acc: 0.9869
# Epoch 46/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0454 - acc: 0.9885 - val_loss: 0.0718 - val_acc: 0.9690
# Epoch 47/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0363 - acc: 0.9893 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 48/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0367 - acc: 0.9897 - val_loss: 0.1323 - val_acc: 0.9550
# Epoch 49/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0352 - acc: 0.9911 - val_loss: 0.0121 - val_acc: 0.9972
# Epoch 50/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0305 - acc: 0.9916 - val_loss: 0.0994 - val_acc: 0.9747
# Epoch 51/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0272 - acc: 0.9928 - val_loss: 0.1685 - val_acc: 0.9456
# Epoch 52/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0415 - acc: 0.9894 - val_loss: 0.0939 - val_acc: 0.9709
# Epoch 53/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0235 - acc: 0.9933 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 54/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0193 - acc: 0.9949 - val_loss: 0.1092 - val_acc: 0.9606
# Epoch 55/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0186 - acc: 0.9941 - val_loss: 0.0554 - val_acc: 0.9822
# Epoch 56/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0449 - acc: 0.9889 - val_loss: 0.0025 - val_acc: 1.0000
# Epoch 57/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0272 - acc: 0.9932 - val_loss: 0.2202 - val_acc: 0.9184
# Epoch 58/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0273 - acc: 0.9941 - val_loss: 0.1051 - val_acc: 0.9597
# Epoch 59/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0244 - acc: 0.9920 - val_loss: 0.0070 - val_acc: 0.9972
# Epoch 60/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0249 - acc: 0.9934 - val_loss: 0.0732 - val_acc: 0.9728
# Epoch 61/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0377 - acc: 0.9903 - val_loss: 0.1472 - val_acc: 0.9465
# Epoch 62/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0121 - acc: 0.9964 - val_loss: 0.4034 - val_acc: 0.9043
# Epoch 63/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0303 - acc: 0.9924 - val_loss: 0.0582 - val_acc: 0.9944
# Epoch 64/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0344 - acc: 0.9900 - val_loss: 0.0249 - val_acc: 0.9906
# Epoch 65/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0241 - acc: 0.9932 - val_loss: 0.0288 - val_acc: 0.9934
# Epoch 66/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0366 - acc: 0.9917 - val_loss: 0.0528 - val_acc: 0.9812
# Epoch 67/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0199 - acc: 0.9945 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 68/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0257 - acc: 0.9923 - val_loss: 0.0154 - val_acc: 0.9944
# Epoch 69/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0220 - acc: 0.9930 - val_loss: 0.0123 - val_acc: 0.9962
# Epoch 70/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0240 - acc: 0.9932 - val_loss: 0.0490 - val_acc: 0.9822
# Epoch 71/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0194 - acc: 0.9938 - val_loss: 0.0521 - val_acc: 0.9850
# Epoch 72/100
# 9590/9590 [==============================] - 20s 2ms/sample - loss: 0.0248 - acc: 0.9932 - val_loss: 0.6214 - val_acc: 0.7842
# Epoch 73/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0288 - acc: 0.9921 - val_loss: 0.0026 - val_acc: 0.9991
# Epoch 74/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0165 - acc: 0.9965 - val_loss: 0.0691 - val_acc: 0.9850
# Epoch 75/100
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0193 - acc: 0.9940 - val_loss: 0.0358 - val_acc: 0.9916
# Epoch 76/100
# 9584/9590 [============================>.] - ETA: 0s - loss: 0.0245 - acc: 0.9941Restoring model weights from the end of the best epoch.
# 9590/9590 [==============================] - 21s 2ms/sample - loss: 0.0245 - acc: 0.9941 - val_loss: 0.0050 - val_acc: 0.9981
# Epoch 00076: early stopping

# %%
print('precision mean by class', np.array(all_base_precision).mean(axis=0))
print('precision sdev by class', np.array(all_base_precision).std(axis=0))

print('macro precision mean', np.array(all_macro_precision).mean())
print('macro precision sdev', np.array(all_macro_precision).std())


print('recall mean', np.array(all_base_recall).mean(axis=0))
print('recall sdev', np.array(all_base_recall).std(axis=0))

print('macro recall mean', np.array(all_macro_recall).mean())
print('macro recall sdev', np.array(all_macro_recall).std())

print('f1 mean', np.array(all_f1).mean(axis=0))
print('f1 sdev', np.array(all_f1).std(axis=0))

print('macro f1 mean', np.array(all_macro_f1).mean())
print('macro f1 sdev', np.array(all_macro_f1).std())

print('accuracy mean', np.array(all_accuracy).mean())
print('accuracy sdev', np.array(all_accuracy).std())
# Out:
# precision mean by class [1.         0.96551779 0.8284585  0.94167518 0.96618964 0.94185393
#  0.84444127 0.94478943]
# precision sdev by class [0.         0.03250365 0.13333346 0.03401147 0.02761283 0.01917726
#  0.09627812 0.04018391]
# macro precision mean 0.9291157173562492
# macro precision sdev 0.032931958077054554
# recall mean [0.88       0.87       0.77628458 0.95310734 0.98078078 0.95150245
#  0.75066667 0.93558642]
# recall sdev [0.16       0.08049845 0.10376078 0.03246056 0.01526518 0.02292103
#  0.23321807 0.04295068]
# macro recall mean 0.8872410303319509
# macro recall sdev 0.03616541535505121
# f1 mean [0.92777778 0.91307034 0.7984585  0.9467461  0.97305053 0.94630434
#  0.76288288 0.93892768]
# f1 sdev [0.09875772 0.04813142 0.10528686 0.02331601 0.01226612 0.01123122
#  0.16694026 0.02467456]
# macro f1 mean 0.9009022691850068
# macro f1 sdev 0.030285120637980747
# accuracy mean 0.9473257333640847
# accuracy sdev 0.017105111110293458

# %%
# Plot all K-Fold ROC curves

for i in range(n_split):
    _, axs = plt.subplots(ncols=1)
    axs.set(xlabel='False Positive Rate',ylabel='True Positive Rate', title='ROC Curve K-Fold#'+str(i+1))
    for j in range(n_classes):
        auc_val = auc(all_fpr[i][j], all_tpr[i][j])
        auc_val = np.around(auc_val,4)
        sns.lineplot(x=all_fpr[i][j],y=all_tpr[i][j],ax=axs, label='Class '+ getSpecies(j) +' (area = ' + str(auc_val) + ')', legend='brief')

# %%
#Plot all K-Fold Precision/Recall curves
for i in range(n_split):
    _, axs = plt.subplots(ncols=1)
    axs.set(xlabel='Recall',ylabel='Precision', title='Precision/Recall Curve K-Fold#'+str(i+1))
    for j in range(n_classes):
        sns.lineplot(x=all_recall[i][j],y=all_precision[i][j],ax=axs, label='Class '+ getSpecies(j), legend='brief')

# %%
## Plot all K-Fold confusion matrices
import numpy as np
import matplotlib.pylab as pl
import matplotlib.gridspec as gridspec
from matplotlib import pyplot as plt

# Create 1X 5 sub plots
# gs = gridspec.GridSpec(1,n_split)
figs=[]
for i in range(n_split):
    figs.append(plt.figure())
    
for i in range(n_split):
    print('Confusion Matrix K-Fold #'+ str(i+1)+"\n")
    print(all_cm[i])
    print("\n")
    
    ax=figs[i].add_subplot()
    sns.heatmap(all_cm[i], annot=True, ax = ax); #annot=True to annotate cells

    
    # labels, title and ticks
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
    ax.set_title('Confusion Matrix K-Fold #'+ str(i+1)); 
    ax.xaxis.set_ticklabels(labels,rotation=45); ax.yaxis.set_ticklabels(labels,rotation=45);
# Out:
# Confusion Matrix K-Fold #1
#
# [[  5   0   0   0   0   0   0   0]
#  [  0  21   0   0   0   2   2   0]
#  [  0   0  13   1   1   0   6   1]
#  [  0   0   0  55   0   3   1   0]
#  [  0   1   5   3 317   0   2   5]
#  [  0   0   2   0   0  52   0   0]
#  [  0   0   0   1   0   0  23   1]
#  [  0   0   2   2   3   0   0  74]]
#
#
# Confusion Matrix K-Fold #2
#
# [[  5   0   0   0   0   0   0   0]
#  [  0  21   0   0   4   0   0   0]
#  [  0   0  20   1   2   0   0   0]
#  [  0   0   0  59   0   1   0   0]
#  [  0   0   1   0 331   0   0   1]
#  [  0   2   0   1   2  48   0   0]
#  [  0   0   2   0  15   0   7   0]
#  [  0   0   0   0   9   1   1  70]]
#
#
# Confusion Matrix K-Fold #3
#
# [[  3   0   0   0   0   0   2   0]
#  [  0  18   0   0   4   1   1   0]
#  [  0   0  17   2   2   0   1   1]
#  [  0   0   0  58   1   1   0   0]
#  [  0   0   0   1 329   1   0   2]
#  [  0   0   0   1   1  52   0   0]
#  [  0   0   0   1   1   0  21   1]
#  [  0   0   0   0   0   0   1  80]]
#
#
# Confusion Matrix K-Fold #4
#
# [[  5   0   0   0   0   0   0   0]
#  [  0  24   0   0   0   1   0   0]
#  [  0   0  19   1   2   0   0   0]
#  [  0   0   0  59   0   1   0   0]
#  [  0   0   1   0 330   0   2   0]
#  [  0   0   0   2   0  52   0   0]
#  [  0   0   1   0   1   0  21   1]
#  [  0   0   1   0   3   0   0  76]]
#
#
# Confusion Matrix K-Fold #5
#
# [[  4   0   0   0   1   0   0   0]
#  [  0  24   0   0   1   0   0   0]
#  [  0   1  18   1   1   0   0   1]
#  [  0   0   2  54   0   4   0   0]
#  [  0   0   0   0 326   0   0   7]
#  [  0   0   1   0   0  52   1   0]
#  [  0   0   1   0   2   0  19   2]
#  [  0   0   0   0   3   0   0  77]]

# %%
## plot macro cm

sum_all_cm=np.zeros((n_classes,n_classes)).astype('int64')
for i in range(n_split):
    sum_all_cm+=all_cm[i]
    
    
#plot 
figs=[]
for i in range(2):
    figs.append(plt.figure())
       
print("sum of all confuion matrices\n",sum_all_cm)
ax=figs[0].add_subplot()
sns.heatmap(sum_all_cm, annot=True, ax = ax);

avg_all_cm=np.divide(sum_all_cm,n_split).astype('int64')
print("\naverage of all confuion matrices\n",avg_all_cm)
ax=figs[1].add_subplot()
sns.heatmap(avg_all_cm, annot=True, ax = ax);
# Out:
# sum of all confuion matrices
#  [[  22    0    0    0    1    0    2    0]
#  [   0  108    0    0    9    4    3    0]
#  [   0    1   87    6    8    0    7    3]
#  [   0    0    2  285    1   10    1    0]
#  [   0    1    7    4 1633    1    4   15]
#  [   0    2    3    4    3  256    1    0]
#  [   0    0    4    2   19    0   91    5]
#  [   0    0    3    2   18    1    2  377]]
#
# average of all confuion matrices
#  [[  4   0   0   0   0   0   0   0]
#  [  0  21   0   0   1   0   0   0]
#  [  0   0  17   1   1   0   1   0]
#  [  0   0   0  57   0   2   0   0]
#  [  0   0   1   0 326   0   0   3]
#  [  0   0   0   0   0  51   0   0]
#  [  0   0   0   0   3   0  18   1]
#  [  0   0   0   0   3   0   0  75]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


cm= sum_all_cm/ sum_all_cm.astype(np.float).sum(axis=1,keepdims = True)
cm = (np.around(cm,2))
print(cm)


labels = ['A.tridens','E.bottae','M.emarginatus','P.kuhli','R.muscatellum','R.nasutus', 'R.aegyptius', 'T.perforatus']


ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labels,rotation=45); ax.yaxis.set_ticklabels(labels,rotation=45);
# Out:
# [[0.88 0.   0.   0.   0.04 0.   0.08 0.  ]
#  [0.   0.87 0.   0.   0.07 0.03 0.02 0.  ]
#  [0.   0.01 0.78 0.05 0.07 0.   0.06 0.03]
#  [0.   0.   0.01 0.95 0.   0.03 0.   0.  ]
#  [0.   0.   0.   0.   0.98 0.   0.   0.01]
#  [0.   0.01 0.01 0.01 0.01 0.95 0.   0.  ]
#  [0.   0.   0.03 0.02 0.16 0.   0.75 0.04]
#  [0.   0.   0.01 0.   0.04 0.   0.   0.94]]
